# %% [markdown]
# # Load audio data to array numpy

# %%
import os
import librosa

genres = ['blues', 'classical', 'country', 'disco', 'hiphop', 
          'jazz', 'metal', 'pop', 'reggae', 'rock']

audio_files = {}

for g in genres:
  audio_files[g] = []

for g in genres:
  for audio in os.listdir(f'./genres/{g}'):
    # Audio loaded as [ndarray, float]
    audio_files[g].append(librosa.core.load(f'./genres/{g}/{audio}'))

# %% [markdown]
# # Preprocessing

# %%
import numpy as np

mel_specs = []
mel_specs_test = []

for g in genres:

  for audio in audio_files[g]:

    y = audio[0]
    sr = audio[1]

    # Generate log power spectrogram
    S = np.abs(librosa.stft(y))
    spect = librosa.power_to_db(S**2, ref=np.median)

    mel_specs_test.append(spect)

    # Slice to have same shapes for all
    spect = spect[:1000,:1220]

    # Compress for the model
    new_shape = (100,122)
    block_height = spect.shape[0] // new_shape[0]
    block_width = spect.shape[1] // new_shape[1]
    downsampled_array = spect.reshape(new_shape[0], block_height, new_shape[1], block_width).mean(3).mean(1)

    mel_specs.append(downsampled_array)
        
X = np.array(mel_specs)

# %% [markdown]
# # See images generated

# %%
import matplotlib.pyplot as plt

# Specify the dimensions of the plot
fig, ax = plt.subplots(figsize=(10, 10))

# Add x and y axis titles
ax.set_xlabel('Time')
ax.set_ylabel('Frequency')

# Display the image
ax.imshow(mel_specs[0], cmap='inferno')

# Show the plot
plt.show()

# %% [markdown]
# # Train test split

# %% [markdown]
# ### Import

# %%
import tensorflow as tf
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
# Out:
# 2023-08-09 22:09:57.780855: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-09 22:09:57.811666: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-09 22:09:57.812450: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-09 22:09:58.443583: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Create y

# %%
# TODO: Delete duplicated jazz sample (54)
y_cnn = []
for i in range(len(genres)):
  y_cnn += 100*[i] # On a 100 images pour chaque genre

y_cnn = to_categorical(np.array(y_cnn))

# %% [markdown]
# ### Train test split

# %%
x_cnn_train, x_cnn_test, y_cnn_train, y_cnn_test = train_test_split(X, y_cnn, test_size=0.2)

# %% [markdown]
# # Model

# %% [markdown]
# ### Neural networks layers

# %%
import tensorflow as tf

model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Conv2D(filters=16, kernel_size=(3, 3), activation='relu', input_shape=(100, 122, 1)))
model.add(tf.keras.layers.Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(tf.keras.layers.Flatten())

model.add(tf.keras.layers.Dense(units=128, activation='relu'))
model.add(tf.keras.layers.Dropout(rate=0.25))

model.add(tf.keras.layers.Dense(units=64, activation='relu'))
model.add(tf.keras.layers.Dropout(rate=0.5))

model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 120, 16)       160
#
#  conv2d_1 (Conv2D)           (None, 98, 120, 16)       2320
#
#  max_pooling2d (MaxPooling2  (None, 49, 60, 16)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 49, 60, 32)        4640
#
#  conv2d_3 (Conv2D)           (None, 49, 60, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 24, 30, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 24, 30, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 24, 30, 64)        36928
#
#  conv2d_6 (Conv2D)           (None, 24, 30, 64)        36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 12, 15, 64)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 12, 15, 128)       73856
#
#  conv2d_8 (Conv2D)           (None, 12, 15, 128)       147584
#
#  conv2d_9 (Conv2D)           (None, 12, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPoolin  (None, 6, 7, 128)         0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 6, 7, 256)         295168
#
#  conv2d_11 (Conv2D)          (None, 6, 7, 256)         590080
#
#  conv2d_12 (Conv2D)          (None, 6, 7, 256)         590080
#
#  max_pooling2d_4 (MaxPoolin  (None, 3, 3, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 128)               295040
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 2257018 (8.61 MB)
# 2023-08-09 22:09:59.197447: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-09 22:09:59.216671: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Trainable params: 2257018 (8.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Compile

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(
    loss="categorical_crossentropy",
    optimizer=optimizer,
    metrics=["accuracy"]
)

# %% [markdown]
# ### Fit

# %%
history = model.fit(x_cnn_train,
                    y_cnn_train,
                    epochs=100,
                    batch_size=30,
                    validation_data = (x_cnn_test,y_cnn_test))
# Out:
# Epoch 1/100
# 27/27 [==============================] - 10s 322ms/step - loss: 2.2921 - accuracy: 0.1350 - val_loss: 2.2310 - val_accuracy: 0.2750
# Epoch 2/100
# 27/27 [==============================] - 8s 286ms/step - loss: 2.2298 - accuracy: 0.1612 - val_loss: 2.0787 - val_accuracy: 0.2950
# Epoch 3/100
# 27/27 [==============================] - 8s 281ms/step - loss: 2.2178 - accuracy: 0.1975 - val_loss: 2.0848 - val_accuracy: 0.3050
# Epoch 4/100
# 27/27 [==============================] - 7s 276ms/step - loss: 2.1830 - accuracy: 0.2175 - val_loss: 2.0994 - val_accuracy: 0.3000
# Epoch 5/100
# 27/27 [==============================] - 7s 274ms/step - loss: 2.1702 - accuracy: 0.2188 - val_loss: 2.1073 - val_accuracy: 0.2800
# Epoch 6/100
# 27/27 [==============================] - 7s 274ms/step - loss: 2.1137 - accuracy: 0.2512 - val_loss: 2.0605 - val_accuracy: 0.2650
# Epoch 7/100
# 27/27 [==============================] - 7s 274ms/step - loss: 2.0809 - accuracy: 0.2500 - val_loss: 1.8796 - val_accuracy: 0.3400
# Epoch 8/100
# 27/27 [==============================] - 7s 274ms/step - loss: 2.0327 - accuracy: 0.2600 - val_loss: 1.8387 - val_accuracy: 0.3250
# Epoch 9/100
# 27/27 [==============================] - 8s 279ms/step - loss: 1.9981 - accuracy: 0.2837 - val_loss: 1.7874 - val_accuracy: 0.3500
# Epoch 10/100
# 27/27 [==============================] - 8s 282ms/step - loss: 1.9625 - accuracy: 0.2800 - val_loss: 1.8362 - val_accuracy: 0.3300
# Epoch 11/100
# 27/27 [==============================] - 7s 276ms/step - loss: 1.9624 - accuracy: 0.2875 - val_loss: 1.7516 - val_accuracy: 0.3500
# Epoch 12/100
# 27/27 [==============================] - 7s 271ms/step - loss: 1.8710 - accuracy: 0.3237 - val_loss: 1.7493 - val_accuracy: 0.3850
# Epoch 13/100
# 27/27 [==============================] - 7s 274ms/step - loss: 1.8778 - accuracy: 0.3150 - val_loss: 1.6959 - val_accuracy: 0.4050
# Epoch 14/100
# 27/27 [==============================] - 7s 273ms/step - loss: 1.8122 - accuracy: 0.3438 - val_loss: 1.7051 - val_accuracy: 0.3750
# Epoch 15/100
# 27/27 [==============================] - 7s 273ms/step - loss: 1.8592 - accuracy: 0.3275 - val_loss: 1.7412 - val_accuracy: 0.4150
# Epoch 16/100
# 27/27 [==============================] - 7s 271ms/step - loss: 1.8428 - accuracy: 0.3150 - val_loss: 1.6411 - val_accuracy: 0.4350
# Epoch 17/100
# 27/27 [==============================] - 8s 283ms/step - loss: 1.7582 - accuracy: 0.3550 - val_loss: 1.6943 - val_accuracy: 0.4000
# Epoch 18/100
# 27/27 [==============================] - 8s 281ms/step - loss: 1.7628 - accuracy: 0.3537 - val_loss: 1.6856 - val_accuracy: 0.4100
# Epoch 19/100
# 27/27 [==============================] - 8s 282ms/step - loss: 1.6962 - accuracy: 0.3875 - val_loss: 1.5613 - val_accuracy: 0.4900
# Epoch 20/100
# 27/27 [==============================] - 8s 285ms/step - loss: 1.6596 - accuracy: 0.3738 - val_loss: 1.6229 - val_accuracy: 0.4600
# Epoch 21/100
# 27/27 [==============================] - 8s 279ms/step - loss: 1.6342 - accuracy: 0.3925 - val_loss: 1.5561 - val_accuracy: 0.4900
# Epoch 22/100
# 27/27 [==============================] - 7s 278ms/step - loss: 1.6413 - accuracy: 0.3950 - val_loss: 1.5308 - val_accuracy: 0.5150
# Epoch 23/100
# 27/27 [==============================] - 8s 279ms/step - loss: 1.6184 - accuracy: 0.3938 - val_loss: 1.5468 - val_accuracy: 0.4900
# Epoch 24/100
# 27/27 [==============================] - 7s 273ms/step - loss: 1.5736 - accuracy: 0.4250 - val_loss: 1.5566 - val_accuracy: 0.4500
# Epoch 25/100
# 27/27 [==============================] - 8s 281ms/step - loss: 1.5916 - accuracy: 0.4250 - val_loss: 1.5196 - val_accuracy: 0.5000
# Epoch 26/100
# 27/27 [==============================] - 8s 280ms/step - loss: 1.5632 - accuracy: 0.4338 - val_loss: 1.8031 - val_accuracy: 0.3900
# Epoch 27/100
# 27/27 [==============================] - 8s 280ms/step - loss: 1.6034 - accuracy: 0.4150 - val_loss: 1.5189 - val_accuracy: 0.4850
# Epoch 28/100
# 27/27 [==============================] - 7s 278ms/step - loss: 1.5871 - accuracy: 0.4137 - val_loss: 1.5555 - val_accuracy: 0.4850
# Epoch 29/100
# 27/27 [==============================] - 7s 274ms/step - loss: 1.5105 - accuracy: 0.4538 - val_loss: 1.5542 - val_accuracy: 0.5000
# Epoch 30/100
# 27/27 [==============================] - 7s 270ms/step - loss: 1.4770 - accuracy: 0.4762 - val_loss: 1.4555 - val_accuracy: 0.5200
# Epoch 31/100
# 27/27 [==============================] - 7s 270ms/step - loss: 1.3821 - accuracy: 0.4975 - val_loss: 1.4732 - val_accuracy: 0.5000
# Epoch 32/100
# 27/27 [==============================] - 8s 280ms/step - loss: 1.4747 - accuracy: 0.4600 - val_loss: 1.4808 - val_accuracy: 0.5000
# Epoch 33/100
# 27/27 [==============================] - 8s 293ms/step - loss: 1.3806 - accuracy: 0.4988 - val_loss: 1.4473 - val_accuracy: 0.5400
# Epoch 34/100
# 27/27 [==============================] - 7s 277ms/step - loss: 1.3461 - accuracy: 0.5163 - val_loss: 1.3952 - val_accuracy: 0.5600
# Epoch 35/100
# 27/27 [==============================] - 8s 278ms/step - loss: 1.4564 - accuracy: 0.4812 - val_loss: 1.5559 - val_accuracy: 0.4900
# Epoch 36/100
# 27/27 [==============================] - 8s 277ms/step - loss: 1.3990 - accuracy: 0.4975 - val_loss: 1.4124 - val_accuracy: 0.5250
# Epoch 37/100
# 27/27 [==============================] - 8s 285ms/step - loss: 1.3947 - accuracy: 0.5138 - val_loss: 1.4867 - val_accuracy: 0.5050
# Epoch 38/100
# 27/27 [==============================] - 7s 276ms/step - loss: 1.3600 - accuracy: 0.4812 - val_loss: 1.4165 - val_accuracy: 0.5550
# Epoch 39/100
# 27/27 [==============================] - 7s 277ms/step - loss: 1.2803 - accuracy: 0.5263 - val_loss: 1.4608 - val_accuracy: 0.5350
# Epoch 40/100
# 27/27 [==============================] - 7s 277ms/step - loss: 1.2709 - accuracy: 0.5375 - val_loss: 1.4219 - val_accuracy: 0.5700
# Epoch 41/100
# 27/27 [==============================] - 8s 284ms/step - loss: 1.2061 - accuracy: 0.5750 - val_loss: 1.3728 - val_accuracy: 0.5850
# Epoch 42/100
# 27/27 [==============================] - 8s 279ms/step - loss: 1.2352 - accuracy: 0.5425 - val_loss: 1.4853 - val_accuracy: 0.5200
# Epoch 43/100
# 27/27 [==============================] - 7s 278ms/step - loss: 1.2549 - accuracy: 0.5863 - val_loss: 1.6178 - val_accuracy: 0.5350
# Epoch 44/100
# 27/27 [==============================] - 7s 277ms/step - loss: 1.2799 - accuracy: 0.5537 - val_loss: 1.4307 - val_accuracy: 0.5750
# Epoch 45/100
# 27/27 [==============================] - 7s 273ms/step - loss: 1.2021 - accuracy: 0.5800 - val_loss: 1.5544 - val_accuracy: 0.5300
# Epoch 46/100
# 27/27 [==============================] - 7s 275ms/step - loss: 1.2522 - accuracy: 0.5600 - val_loss: 1.4590 - val_accuracy: 0.5500
# Epoch 47/100
# 27/27 [==============================] - 7s 277ms/step - loss: 1.1369 - accuracy: 0.5900 - val_loss: 1.3938 - val_accuracy: 0.5400
# Epoch 48/100
# 27/27 [==============================] - 8s 279ms/step - loss: 1.1486 - accuracy: 0.6050 - val_loss: 1.3468 - val_accuracy: 0.5500
# Epoch 49/100
# 27/27 [==============================] - 7s 278ms/step - loss: 1.0695 - accuracy: 0.6388 - val_loss: 1.3283 - val_accuracy: 0.5700
# Epoch 50/100
# 27/27 [==============================] - 7s 274ms/step - loss: 1.1002 - accuracy: 0.6125 - val_loss: 1.3795 - val_accuracy: 0.5400
# Epoch 51/100
# 27/27 [==============================] - 7s 277ms/step - loss: 1.0774 - accuracy: 0.6300 - val_loss: 1.3685 - val_accuracy: 0.5900
# Epoch 52/100
# 27/27 [==============================] - 7s 272ms/step - loss: 1.0242 - accuracy: 0.6562 - val_loss: 1.3575 - val_accuracy: 0.5850
# Epoch 53/100
# 27/27 [==============================] - 7s 276ms/step - loss: 0.9858 - accuracy: 0.6625 - val_loss: 1.3947 - val_accuracy: 0.6050
# Epoch 54/100
# 27/27 [==============================] - 7s 276ms/step - loss: 0.9460 - accuracy: 0.6675 - val_loss: 1.4213 - val_accuracy: 0.6050
# Epoch 55/100
# 27/27 [==============================] - 8s 278ms/step - loss: 0.9483 - accuracy: 0.6837 - val_loss: 1.4000 - val_accuracy: 0.5850
# Epoch 56/100
# 27/27 [==============================] - 7s 275ms/step - loss: 0.9272 - accuracy: 0.6675 - val_loss: 1.5583 - val_accuracy: 0.5950
# Epoch 57/100
# 27/27 [==============================] - 7s 277ms/step - loss: 1.0027 - accuracy: 0.6375 - val_loss: 1.4708 - val_accuracy: 0.5800
# Epoch 58/100
# 27/27 [==============================] - 7s 272ms/step - loss: 0.9615 - accuracy: 0.6587 - val_loss: 1.4702 - val_accuracy: 0.5750
# Epoch 59/100
# 27/27 [==============================] - 7s 272ms/step - loss: 0.8989 - accuracy: 0.6975 - val_loss: 1.5984 - val_accuracy: 0.5200
# Epoch 60/100
# 27/27 [==============================] - 7s 271ms/step - loss: 0.8146 - accuracy: 0.7163 - val_loss: 1.4825 - val_accuracy: 0.6350
# Epoch 61/100
# 27/27 [==============================] - 7s 273ms/step - loss: 0.7909 - accuracy: 0.7200 - val_loss: 1.4787 - val_accuracy: 0.6150
# Epoch 62/100
# 27/27 [==============================] - 7s 276ms/step - loss: 0.9057 - accuracy: 0.6975 - val_loss: 1.6926 - val_accuracy: 0.5750
# Epoch 63/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.7858 - accuracy: 0.7450 - val_loss: 1.6937 - val_accuracy: 0.5850
# Epoch 64/100
# 27/27 [==============================] - 8s 279ms/step - loss: 0.7650 - accuracy: 0.7287 - val_loss: 1.4233 - val_accuracy: 0.6250
# Epoch 65/100
# 27/27 [==============================] - 7s 277ms/step - loss: 0.6906 - accuracy: 0.7663 - val_loss: 1.6899 - val_accuracy: 0.6000
# Epoch 66/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.7904 - accuracy: 0.7450 - val_loss: 1.3908 - val_accuracy: 0.6350
# Epoch 67/100
# 27/27 [==============================] - 8s 287ms/step - loss: 0.7318 - accuracy: 0.7487 - val_loss: 2.0035 - val_accuracy: 0.5550
# Epoch 68/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.7367 - accuracy: 0.7538 - val_loss: 1.4776 - val_accuracy: 0.6500
# Epoch 69/100
# 27/27 [==============================] - 7s 273ms/step - loss: 0.6612 - accuracy: 0.7650 - val_loss: 1.6725 - val_accuracy: 0.6200
# Epoch 70/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.6495 - accuracy: 0.7613 - val_loss: 1.6860 - val_accuracy: 0.6250
# Epoch 71/100
# 27/27 [==============================] - 7s 277ms/step - loss: 0.6645 - accuracy: 0.7625 - val_loss: 1.5906 - val_accuracy: 0.6400
# Epoch 72/100
# 27/27 [==============================] - 7s 273ms/step - loss: 0.5993 - accuracy: 0.7837 - val_loss: 1.6347 - val_accuracy: 0.6250
# Epoch 73/100
# 27/27 [==============================] - 7s 271ms/step - loss: 0.5850 - accuracy: 0.7912 - val_loss: 1.8220 - val_accuracy: 0.5900
# Epoch 74/100
# 27/27 [==============================] - 7s 273ms/step - loss: 0.6426 - accuracy: 0.7925 - val_loss: 1.4756 - val_accuracy: 0.6500
# Epoch 75/100
# 27/27 [==============================] - 7s 273ms/step - loss: 0.5503 - accuracy: 0.8025 - val_loss: 1.5242 - val_accuracy: 0.6700
# Epoch 76/100
# 27/27 [==============================] - 7s 269ms/step - loss: 0.6285 - accuracy: 0.7900 - val_loss: 1.5611 - val_accuracy: 0.6600
# Epoch 77/100
# 27/27 [==============================] - 7s 274ms/step - loss: 0.5400 - accuracy: 0.8150 - val_loss: 1.7939 - val_accuracy: 0.6400
# Epoch 78/100
# 27/27 [==============================] - 7s 276ms/step - loss: 0.5290 - accuracy: 0.8087 - val_loss: 1.7941 - val_accuracy: 0.6300
# Epoch 79/100
# 27/27 [==============================] - 7s 271ms/step - loss: 0.5536 - accuracy: 0.8175 - val_loss: 1.7071 - val_accuracy: 0.6250
# Epoch 80/100
# 27/27 [==============================] - 7s 274ms/step - loss: 0.4963 - accuracy: 0.8425 - val_loss: 1.9974 - val_accuracy: 0.6050
# Epoch 81/100
# 27/27 [==============================] - 7s 276ms/step - loss: 0.4886 - accuracy: 0.8413 - val_loss: 1.6267 - val_accuracy: 0.6650
# Epoch 82/100
# 27/27 [==============================] - 7s 274ms/step - loss: 0.4716 - accuracy: 0.8400 - val_loss: 1.9047 - val_accuracy: 0.6400
# Epoch 83/100
# 27/27 [==============================] - 7s 274ms/step - loss: 0.4186 - accuracy: 0.8625 - val_loss: 2.0323 - val_accuracy: 0.6150
# Epoch 84/100
# 27/27 [==============================] - 7s 270ms/step - loss: 0.4474 - accuracy: 0.8525 - val_loss: 2.2571 - val_accuracy: 0.5850
# Epoch 85/100
# 27/27 [==============================] - 7s 275ms/step - loss: 0.4631 - accuracy: 0.8400 - val_loss: 1.7404 - val_accuracy: 0.6450
# Epoch 86/100
# 27/27 [==============================] - 7s 274ms/step - loss: 0.4637 - accuracy: 0.8438 - val_loss: 1.9198 - val_accuracy: 0.6350
# Epoch 87/100
# 27/27 [==============================] - 7s 272ms/step - loss: 0.3440 - accuracy: 0.8763 - val_loss: 1.9283 - val_accuracy: 0.6800
# Epoch 88/100
# 27/27 [==============================] - 7s 274ms/step - loss: 0.4389 - accuracy: 0.8537 - val_loss: 2.0853 - val_accuracy: 0.5950
# Epoch 89/100
# 27/27 [==============================] - 7s 270ms/step - loss: 0.4005 - accuracy: 0.8712 - val_loss: 1.8354 - val_accuracy: 0.6450
# Epoch 90/100
# 27/27 [==============================] - 7s 271ms/step - loss: 0.3888 - accuracy: 0.8900 - val_loss: 1.8452 - val_accuracy: 0.6400
# Epoch 91/100
# 27/27 [==============================] - 7s 268ms/step - loss: 0.3807 - accuracy: 0.8700 - val_loss: 2.1561 - val_accuracy: 0.6350
# Epoch 92/100
# 27/27 [==============================] - 7s 271ms/step - loss: 0.3606 - accuracy: 0.8725 - val_loss: 2.0822 - val_accuracy: 0.6350
# Epoch 93/100
# 27/27 [==============================] - 7s 269ms/step - loss: 0.2822 - accuracy: 0.9013 - val_loss: 1.9702 - val_accuracy: 0.6450
# Epoch 94/100
# 27/27 [==============================] - 7s 268ms/step - loss: 0.2518 - accuracy: 0.9162 - val_loss: 2.1613 - val_accuracy: 0.6350
# Epoch 95/100
# 27/27 [==============================] - 7s 274ms/step - loss: 0.3068 - accuracy: 0.9013 - val_loss: 2.1784 - val_accuracy: 0.6500
# Epoch 96/100
# 27/27 [==============================] - 7s 277ms/step - loss: 0.2856 - accuracy: 0.9000 - val_loss: 2.1610 - val_accuracy: 0.6300
# Epoch 97/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.4165 - accuracy: 0.8637 - val_loss: 1.9713 - val_accuracy: 0.5950
# Epoch 98/100
# 27/27 [==============================] - 7s 275ms/step - loss: 0.3361 - accuracy: 0.9100 - val_loss: 2.1875 - val_accuracy: 0.6500
# Epoch 99/100
# 27/27 [==============================] - 7s 276ms/step - loss: 0.3432 - accuracy: 0.8913 - val_loss: 2.3124 - val_accuracy: 0.6300
# Epoch 100/100
# 27/27 [==============================] - 7s 277ms/step - loss: 0.2534 - accuracy: 0.9175 - val_loss: 2.1453 - val_accuracy: 0.6500

# %% [markdown]
# ### Save

# %%
# model.save("my_model_cnn_clean_v1.keras")

# %% [markdown]
# # Metrics

# %%
loss_curve = history.history["loss"]
acc_curve = history.history["accuracy"]

loss_val_curve = history.history["val_loss"]
acc_val_curve = history.history["val_accuracy"]

plt.plot(loss_curve, label="Train")
plt.plot(loss_val_curve, label="Val")
plt.legend(loc='upper left')
plt.title("Loss")
plt.show()

plt.plot(acc_curve, label="Train")
plt.plot(acc_val_curve, label="Val")
plt.legend(loc='upper left')
plt.title("Accuracy")
plt.show()

# %% [markdown]
# # Predict

# %% [markdown]
# ### Preprocessing

# %%
# audio = librosa.core.load(f'./genres/blues/blues.00000.wav')
# audio = librosa.core.load(f'./genres/blues/blues.00049.wav')
audio = librosa.core.load(f'./genres/disco/disco.00090.wav')
# audio = librosa.core.load(f'./genres/jazz/jazz.00097.wav')
y = audio[0]
sr = audio[1]

# Generate log power spectrogram
S = np.abs(librosa.stft(y))
spect = librosa.power_to_db(S**2, ref=np.median)

# Slice to have same shapes for all
spect = spect[:1000,:1220]

# Compress for the model
new_shape = (100,122)
block_height = spect.shape[0] // new_shape[0]
block_width = spect.shape[1] // new_shape[1]
downsampled_array = spect.reshape(new_shape[0], block_height, new_shape[1], block_width).mean(3).mean(1)

X = np.array([downsampled_array])

# %%
result = model.predict(X, verbose=2)
# Out:
# 1/1 - 0s - 149ms/epoch - 149ms/step

# %%
actual_best = 0
result_label = ""

for i in range(len(genres)):
    actual = result[0][i]
    if actual > actual_best:
        actual_best = actual
        result_label = genres[i]

print(result_label, str(actual_best))
# Out:
# disco 0.9978409
