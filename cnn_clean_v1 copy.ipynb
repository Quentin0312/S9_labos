# %% [markdown]
# Modèle du tuto mis en place

# %% [markdown]
# # Load audio data to array numpy

# %%
import os
import librosa

genres = ['blues', 'classical', 'country', 'disco', 'hiphop', 
          'jazz', 'metal', 'pop', 'reggae', 'rock']

audio_files = {}

for g in genres:
  audio_files[g] = []

for g in genres:
  for audio in os.listdir(f'./genres/{g}'):
    # Audio loaded as [ndarray, float]
    audio_files[g].append(librosa.core.load(f'./genres/{g}/{audio}'))

# %% [markdown]
# # Preprocessing

# %%
import numpy as np

mel_specs = []
mel_specs_test = []

for g in genres:

  for audio in audio_files[g]:

    y = audio[0]
    sr = audio[1]

    # Generate log power spectrogram
    S = np.abs(librosa.stft(y))
    spect = librosa.power_to_db(S**2, ref=np.median)

    mel_specs_test.append(spect)

    # Slice to have same shapes for all
    spect = spect[:1000,:1220]

    # Compress for the model
    new_shape = (100,122)
    block_height = spect.shape[0] // new_shape[0]
    block_width = spect.shape[1] // new_shape[1]
    downsampled_array = spect.reshape(new_shape[0], block_height, new_shape[1], block_width).mean(3).mean(1)

    mel_specs.append(downsampled_array)
        
X = np.array(mel_specs)

# %%
# import librosa.display
# import matplotlib.pyplot

# librosa.display.specshow(mel_specs_test[0])
# print(mel_specs_test[0])

# %% [markdown]
# # See images generated

# %%
import matplotlib.pyplot as plt

# Specify the dimensions of the plot
fig, ax = plt.subplots(figsize=(10, 10))

# Add x and y axis titles
ax.set_xlabel('Time')
ax.set_ylabel('Frequency')

# Display the image
ax.imshow(mel_specs[0], cmap='inferno')

# Show the plot
plt.show()

# %% [markdown]
# # Train test split

# %% [markdown]
# ### Import

# %%
import tensorflow as tf
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
# Out:
# 2023-08-09 15:41:02.430193: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-09 15:41:02.459502: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-09 15:41:02.460039: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-09 15:41:03.088844: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Create y

# %%
# TODO: Delete duplicated jazz sample (54)
y_cnn = []
for i in range(len(genres)):
  y_cnn += 100*[i] # On a 100 images pour chaque genre

y_cnn = to_categorical(np.array(y_cnn))

# %% [markdown]
# ### Train test split

# %%
x_cnn_train, x_cnn_test, y_cnn_train, y_cnn_test = train_test_split(X, y_cnn, test_size=0.2)

# %% [markdown]
# # Model

# %% [markdown]
# ### Neural networks layers

# %%
import tensorflow as tf

# model = tf.keras.models.Sequential()

# model.add(tf.keras.layers.Conv2D(16, kernel_size=(3, 3), activation='relu', input_shape=(100, 122, 1)))
# model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

# model.add(tf.keras.layers.Flatten())
# model.add(tf.keras.layers.Dense(64, activation='relu'))

# model.add(tf.keras.layers.Dense(10, activation='softmax'))
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=(100,122,1)))

model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(tf.keras.layers.Conv2D(64, 
                 kernel_size=(3, 3), 
                 activation='relu'))

model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(tf.keras.layers.Dropout(0.3))

model.add(tf.keras.layers.Conv2D(32, 
                 kernel_size=(3, 3), 
                 activation='relu'))

model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Dense(64, activation='relu'))
model.add(tf.keras.layers.Dense(32, activation='relu'))

model.add(tf.keras.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 120, 32)       320
#
#  max_pooling2d (MaxPooling2  (None, 49, 60, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 47, 58, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 23, 29, 64)        0
#  g2D)
#
#  dropout (Dropout)           (None, 23, 29, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 21, 27, 32)        18464
#
#  max_pooling2d_2 (MaxPoolin  (None, 10, 13, 32)        0
#  g2D)
#
#  flatten (Flatten)           (None, 4160)              0
#
#  dropout_1 (Dropout)         (None, 4160)              0
#
#  dense (Dense)               (None, 64)                266304
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 305994 (1.17 MB)
# Trainable params: 305994 (1.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2023-08-09 15:41:03.858492: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-09 15:41:03.880815: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# ### Compile

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(
    loss="categorical_crossentropy",
    optimizer=optimizer,
    metrics=["accuracy"]
)

# %% [markdown]
# ### Fit

# %%
history = model.fit(x_cnn_train,
                    y_cnn_train,
                    epochs=100,
                    batch_size=30,
                    validation_data = (x_cnn_test,y_cnn_test))
# Out:
# Epoch 1/100
# 27/27 [==============================] - 5s 140ms/step - loss: 2.7408 - accuracy: 0.1275 - val_loss: 2.2578 - val_accuracy: 0.1850
# Epoch 2/100
# 27/27 [==============================] - 3s 123ms/step - loss: 2.2784 - accuracy: 0.1737 - val_loss: 2.2113 - val_accuracy: 0.1750
# Epoch 3/100
# 27/27 [==============================] - 3s 127ms/step - loss: 2.1655 - accuracy: 0.2212 - val_loss: 2.1747 - val_accuracy: 0.1900
# Epoch 4/100
# 27/27 [==============================] - 3s 122ms/step - loss: 2.1126 - accuracy: 0.2387 - val_loss: 2.1406 - val_accuracy: 0.1950
# Epoch 5/100
# 27/27 [==============================] - 3s 123ms/step - loss: 2.0799 - accuracy: 0.2425 - val_loss: 2.1072 - val_accuracy: 0.2050
# Epoch 6/100
# 27/27 [==============================] - 3s 123ms/step - loss: 1.9809 - accuracy: 0.2612 - val_loss: 2.0409 - val_accuracy: 0.2550
# Epoch 7/100
# 27/27 [==============================] - 3s 125ms/step - loss: 1.9200 - accuracy: 0.2788 - val_loss: 2.0155 - val_accuracy: 0.2600
# Epoch 8/100
# 27/27 [==============================] - 4s 144ms/step - loss: 1.8931 - accuracy: 0.3200 - val_loss: 1.9642 - val_accuracy: 0.3150
# Epoch 9/100
# 27/27 [==============================] - 4s 130ms/step - loss: 1.8235 - accuracy: 0.3638 - val_loss: 1.9193 - val_accuracy: 0.3650
# Epoch 10/100
# 27/27 [==============================] - 3s 126ms/step - loss: 1.7691 - accuracy: 0.3575 - val_loss: 1.9135 - val_accuracy: 0.3500
# Epoch 11/100
# 27/27 [==============================] - 3s 126ms/step - loss: 1.6867 - accuracy: 0.3950 - val_loss: 1.8060 - val_accuracy: 0.3800
# Epoch 12/100
# 27/27 [==============================] - 3s 126ms/step - loss: 1.6535 - accuracy: 0.3925 - val_loss: 1.8889 - val_accuracy: 0.3350
# Epoch 13/100
# 27/27 [==============================] - 3s 120ms/step - loss: 1.6457 - accuracy: 0.4338 - val_loss: 1.7465 - val_accuracy: 0.4150
# Epoch 14/100
# 27/27 [==============================] - 3s 126ms/step - loss: 1.6008 - accuracy: 0.4225 - val_loss: 1.7812 - val_accuracy: 0.3650
# Epoch 15/100
# 27/27 [==============================] - 3s 123ms/step - loss: 1.5848 - accuracy: 0.4338 - val_loss: 1.7359 - val_accuracy: 0.4000
# Epoch 16/100
# 27/27 [==============================] - 3s 123ms/step - loss: 1.5495 - accuracy: 0.4538 - val_loss: 1.6799 - val_accuracy: 0.4550
# Epoch 17/100
# 27/27 [==============================] - 3s 126ms/step - loss: 1.4995 - accuracy: 0.4575 - val_loss: 1.7613 - val_accuracy: 0.3800
# Epoch 18/100
# 27/27 [==============================] - 3s 124ms/step - loss: 1.5099 - accuracy: 0.4663 - val_loss: 1.6667 - val_accuracy: 0.4050
# Epoch 19/100
# 27/27 [==============================] - 3s 121ms/step - loss: 1.4403 - accuracy: 0.4538 - val_loss: 1.6498 - val_accuracy: 0.4050
# Epoch 20/100
# 27/27 [==============================] - 3s 118ms/step - loss: 1.3969 - accuracy: 0.5025 - val_loss: 1.6676 - val_accuracy: 0.4050
# Epoch 21/100
# 27/27 [==============================] - 3s 120ms/step - loss: 1.3557 - accuracy: 0.5063 - val_loss: 1.5657 - val_accuracy: 0.4850
# Epoch 22/100
# 27/27 [==============================] - 3s 127ms/step - loss: 1.3598 - accuracy: 0.5075 - val_loss: 1.5639 - val_accuracy: 0.4350
# Epoch 23/100
# 27/27 [==============================] - 3s 125ms/step - loss: 1.3096 - accuracy: 0.5300 - val_loss: 1.6108 - val_accuracy: 0.4100
# Epoch 24/100
# 27/27 [==============================] - 3s 119ms/step - loss: 1.2712 - accuracy: 0.5625 - val_loss: 1.5262 - val_accuracy: 0.4750
# Epoch 25/100
# 27/27 [==============================] - 3s 119ms/step - loss: 1.2771 - accuracy: 0.5550 - val_loss: 1.5420 - val_accuracy: 0.5050
# Epoch 26/100
# 27/27 [==============================] - 3s 120ms/step - loss: 1.2291 - accuracy: 0.5725 - val_loss: 1.4851 - val_accuracy: 0.4900
# Epoch 27/100
# 27/27 [==============================] - 3s 120ms/step - loss: 1.2100 - accuracy: 0.5850 - val_loss: 1.5758 - val_accuracy: 0.4700
# Epoch 28/100
# 27/27 [==============================] - 3s 117ms/step - loss: 1.1794 - accuracy: 0.5875 - val_loss: 1.5443 - val_accuracy: 0.4650
# Epoch 29/100
# 27/27 [==============================] - 3s 123ms/step - loss: 1.1496 - accuracy: 0.6112 - val_loss: 1.4604 - val_accuracy: 0.5100
# Epoch 30/100
# 27/27 [==============================] - 3s 121ms/step - loss: 1.0815 - accuracy: 0.6050 - val_loss: 1.4107 - val_accuracy: 0.5000
# Epoch 31/100
# 27/27 [==============================] - 3s 129ms/step - loss: 1.0824 - accuracy: 0.6187 - val_loss: 1.4441 - val_accuracy: 0.5150
# Epoch 32/100
# 27/27 [==============================] - 3s 128ms/step - loss: 1.0521 - accuracy: 0.6388 - val_loss: 1.4580 - val_accuracy: 0.4900
# Epoch 33/100
# 27/27 [==============================] - 3s 125ms/step - loss: 1.0764 - accuracy: 0.6313 - val_loss: 1.3822 - val_accuracy: 0.5550
# Epoch 34/100
# 27/27 [==============================] - 3s 123ms/step - loss: 1.0051 - accuracy: 0.6675 - val_loss: 1.4184 - val_accuracy: 0.5050
# Epoch 35/100
# 27/27 [==============================] - 3s 124ms/step - loss: 0.9868 - accuracy: 0.6587 - val_loss: 1.4217 - val_accuracy: 0.5050
# Epoch 36/100
# 27/27 [==============================] - 3s 121ms/step - loss: 0.9459 - accuracy: 0.6725 - val_loss: 1.3528 - val_accuracy: 0.4900
# Epoch 37/100
# 27/27 [==============================] - 3s 121ms/step - loss: 0.9581 - accuracy: 0.6737 - val_loss: 1.4117 - val_accuracy: 0.5300
# Epoch 38/100
# 27/27 [==============================] - 3s 127ms/step - loss: 0.9004 - accuracy: 0.6762 - val_loss: 1.3470 - val_accuracy: 0.5650
# Epoch 39/100
# 27/27 [==============================] - 3s 124ms/step - loss: 0.8783 - accuracy: 0.6837 - val_loss: 1.3818 - val_accuracy: 0.5300
# Epoch 40/100
# 27/27 [==============================] - 3s 128ms/step - loss: 0.8500 - accuracy: 0.7175 - val_loss: 1.3012 - val_accuracy: 0.5550
# Epoch 41/100
# 27/27 [==============================] - 3s 119ms/step - loss: 0.8537 - accuracy: 0.7063 - val_loss: 1.3892 - val_accuracy: 0.5700
# Epoch 42/100
# 27/27 [==============================] - 3s 123ms/step - loss: 0.8453 - accuracy: 0.7050 - val_loss: 1.3733 - val_accuracy: 0.5600
# Epoch 43/100
# 27/27 [==============================] - 3s 120ms/step - loss: 0.8212 - accuracy: 0.7237 - val_loss: 1.3798 - val_accuracy: 0.5550
# Epoch 44/100
# 27/27 [==============================] - 3s 126ms/step - loss: 0.7940 - accuracy: 0.7212 - val_loss: 1.3236 - val_accuracy: 0.5600
# Epoch 45/100
# 27/27 [==============================] - 3s 126ms/step - loss: 0.7619 - accuracy: 0.7375 - val_loss: 1.3457 - val_accuracy: 0.5800
# Epoch 46/100
# 27/27 [==============================] - 3s 121ms/step - loss: 0.7334 - accuracy: 0.7350 - val_loss: 1.3306 - val_accuracy: 0.5750
# Epoch 47/100
# 27/27 [==============================] - 3s 117ms/step - loss: 0.7298 - accuracy: 0.7425 - val_loss: 1.4065 - val_accuracy: 0.5250
# Epoch 48/100
# 27/27 [==============================] - 3s 121ms/step - loss: 0.7333 - accuracy: 0.7538 - val_loss: 1.3545 - val_accuracy: 0.5400
# Epoch 49/100
# 27/27 [==============================] - 3s 125ms/step - loss: 0.6918 - accuracy: 0.7650 - val_loss: 1.3800 - val_accuracy: 0.5700
# Epoch 50/100
# 27/27 [==============================] - 3s 123ms/step - loss: 0.6841 - accuracy: 0.7600 - val_loss: 1.3381 - val_accuracy: 0.5350
# Epoch 51/100
# 27/27 [==============================] - 3s 122ms/step - loss: 0.6342 - accuracy: 0.7900 - val_loss: 1.4027 - val_accuracy: 0.5300
# Epoch 52/100
# 27/27 [==============================] - 3s 119ms/step - loss: 0.6447 - accuracy: 0.7750 - val_loss: 1.4464 - val_accuracy: 0.5500
# Epoch 53/100
# 27/27 [==============================] - 3s 122ms/step - loss: 0.6425 - accuracy: 0.7837 - val_loss: 1.3932 - val_accuracy: 0.5700
# Epoch 54/100
# 27/27 [==============================] - 3s 121ms/step - loss: 0.6173 - accuracy: 0.7950 - val_loss: 1.3771 - val_accuracy: 0.5650
# Epoch 55/100
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5989 - accuracy: 0.7850 - val_loss: 1.4314 - val_accuracy: 0.5600
# Epoch 56/100
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5740 - accuracy: 0.7950 - val_loss: 1.3233 - val_accuracy: 0.5650
# Epoch 57/100
# 27/27 [==============================] - 3s 125ms/step - loss: 0.5555 - accuracy: 0.8213 - val_loss: 1.3481 - val_accuracy: 0.5500
# Epoch 58/100
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5481 - accuracy: 0.8238 - val_loss: 1.4158 - val_accuracy: 0.5600
# Epoch 59/100
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5107 - accuracy: 0.8300 - val_loss: 1.4533 - val_accuracy: 0.5600
# Epoch 60/100
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5186 - accuracy: 0.8225 - val_loss: 1.4838 - val_accuracy: 0.5600
# Epoch 61/100
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5076 - accuracy: 0.8250 - val_loss: 1.4546 - val_accuracy: 0.5650
# Epoch 62/100
# 27/27 [==============================] - 3s 120ms/step - loss: 0.4645 - accuracy: 0.8375 - val_loss: 1.4099 - val_accuracy: 0.5200
# Epoch 63/100
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5105 - accuracy: 0.8338 - val_loss: 1.3821 - val_accuracy: 0.5600
# Epoch 64/100
# 27/27 [==============================] - 3s 122ms/step - loss: 0.4515 - accuracy: 0.8512 - val_loss: 1.3864 - val_accuracy: 0.5600
# Epoch 65/100
# 27/27 [==============================] - 3s 120ms/step - loss: 0.4174 - accuracy: 0.8512 - val_loss: 1.4216 - val_accuracy: 0.5550
# Epoch 66/100
# 27/27 [==============================] - 3s 124ms/step - loss: 0.4259 - accuracy: 0.8438 - val_loss: 1.3876 - val_accuracy: 0.5800
# Epoch 67/100
# 27/27 [==============================] - 3s 126ms/step - loss: 0.4128 - accuracy: 0.8625 - val_loss: 1.3670 - val_accuracy: 0.5550
# Epoch 68/100
# 27/27 [==============================] - 3s 123ms/step - loss: 0.4142 - accuracy: 0.8637 - val_loss: 1.3892 - val_accuracy: 0.5800
# Epoch 69/100
# 27/27 [==============================] - 3s 123ms/step - loss: 0.4257 - accuracy: 0.8512 - val_loss: 1.4678 - val_accuracy: 0.6050
# Epoch 70/100
# 27/27 [==============================] - 3s 126ms/step - loss: 0.3989 - accuracy: 0.8600 - val_loss: 1.4814 - val_accuracy: 0.5600
# Epoch 71/100
# 27/27 [==============================] - 3s 124ms/step - loss: 0.3836 - accuracy: 0.8788 - val_loss: 1.4256 - val_accuracy: 0.5800
# Epoch 72/100
# 27/27 [==============================] - 3s 123ms/step - loss: 0.3677 - accuracy: 0.8838 - val_loss: 1.5213 - val_accuracy: 0.5650
# Epoch 73/100
# 27/27 [==============================] - 3s 125ms/step - loss: 0.3533 - accuracy: 0.8775 - val_loss: 1.4723 - val_accuracy: 0.5600
# Epoch 74/100
# 27/27 [==============================] - 3s 125ms/step - loss: 0.3506 - accuracy: 0.8700 - val_loss: 1.4174 - val_accuracy: 0.5800
# Epoch 75/100
# 27/27 [==============================] - 3s 119ms/step - loss: 0.3398 - accuracy: 0.8888 - val_loss: 1.4922 - val_accuracy: 0.5950
# Epoch 76/100
# 27/27 [==============================] - 3s 124ms/step - loss: 0.3304 - accuracy: 0.8950 - val_loss: 1.4269 - val_accuracy: 0.5600
# Epoch 77/100
# 27/27 [==============================] - 3s 126ms/step - loss: 0.2846 - accuracy: 0.9175 - val_loss: 1.4749 - val_accuracy: 0.5500
# Epoch 78/100
# 27/27 [==============================] - 3s 120ms/step - loss: 0.2888 - accuracy: 0.9025 - val_loss: 1.4639 - val_accuracy: 0.5350
# Epoch 79/100
# 27/27 [==============================] - 3s 121ms/step - loss: 0.2926 - accuracy: 0.9125 - val_loss: 1.4120 - val_accuracy: 0.5700
# Epoch 80/100
# 27/27 [==============================] - 3s 124ms/step - loss: 0.2501 - accuracy: 0.9225 - val_loss: 1.4484 - val_accuracy: 0.5650
# Epoch 81/100
# 27/27 [==============================] - 3s 123ms/step - loss: 0.2683 - accuracy: 0.9150 - val_loss: 1.5509 - val_accuracy: 0.5400
# Epoch 82/100
# 27/27 [==============================] - 3s 125ms/step - loss: 0.2366 - accuracy: 0.9425 - val_loss: 1.4498 - val_accuracy: 0.5800
# Epoch 83/100
# 27/27 [==============================] - 3s 122ms/step - loss: 0.2554 - accuracy: 0.9187 - val_loss: 1.5211 - val_accuracy: 0.5700
# Epoch 84/100
# 27/27 [==============================] - 3s 121ms/step - loss: 0.2373 - accuracy: 0.9287 - val_loss: 1.4717 - val_accuracy: 0.5800
# Epoch 85/100
# 27/27 [==============================] - 3s 125ms/step - loss: 0.2698 - accuracy: 0.9187 - val_loss: 1.4504 - val_accuracy: 0.5700
# Epoch 86/100
# 27/27 [==============================] - 3s 123ms/step - loss: 0.2312 - accuracy: 0.9287 - val_loss: 1.4525 - val_accuracy: 0.5450
# Epoch 87/100
# 27/27 [==============================] - 3s 122ms/step - loss: 0.2264 - accuracy: 0.9362 - val_loss: 1.5650 - val_accuracy: 0.5600
# Epoch 88/100
# 27/27 [==============================] - 3s 124ms/step - loss: 0.2357 - accuracy: 0.9262 - val_loss: 1.5389 - val_accuracy: 0.5500
# Epoch 89/100
# 27/27 [==============================] - 3s 126ms/step - loss: 0.2412 - accuracy: 0.9250 - val_loss: 1.5011 - val_accuracy: 0.5400
# Epoch 90/100
# 27/27 [==============================] - 3s 122ms/step - loss: 0.2197 - accuracy: 0.9388 - val_loss: 1.4858 - val_accuracy: 0.5550
# Epoch 91/100
# 27/27 [==============================] - 3s 124ms/step - loss: 0.2184 - accuracy: 0.9450 - val_loss: 1.5103 - val_accuracy: 0.5550
# Epoch 92/100
# 27/27 [==============================] - 3s 124ms/step - loss: 0.1990 - accuracy: 0.9375 - val_loss: 1.6433 - val_accuracy: 0.5450
# Epoch 93/100
# 27/27 [==============================] - 3s 123ms/step - loss: 0.2047 - accuracy: 0.9362 - val_loss: 1.5722 - val_accuracy: 0.5650
# Epoch 94/100
# 27/27 [==============================] - 3s 129ms/step - loss: 0.1844 - accuracy: 0.9525 - val_loss: 1.5105 - val_accuracy: 0.5700
# Epoch 95/100
# 27/27 [==============================] - 3s 123ms/step - loss: 0.1661 - accuracy: 0.9538 - val_loss: 1.6235 - val_accuracy: 0.5600
# Epoch 96/100
# 27/27 [==============================] - 3s 123ms/step - loss: 0.1850 - accuracy: 0.9388 - val_loss: 1.5468 - val_accuracy: 0.5900
# Epoch 97/100
# 27/27 [==============================] - 3s 122ms/step - loss: 0.1733 - accuracy: 0.9463 - val_loss: 1.5645 - val_accuracy: 0.5750
# Epoch 98/100
# 27/27 [==============================] - 3s 119ms/step - loss: 0.1652 - accuracy: 0.9513 - val_loss: 1.6301 - val_accuracy: 0.5700
# Epoch 99/100
# 27/27 [==============================] - 3s 120ms/step - loss: 0.1860 - accuracy: 0.9413 - val_loss: 1.6188 - val_accuracy: 0.5700
# Epoch 100/100
# 27/27 [==============================] - 3s 122ms/step - loss: 0.1613 - accuracy: 0.9500 - val_loss: 1.5934 - val_accuracy: 0.5550

# %% [markdown]
# ### Save

# %%
# model.save("my_model_cnn_clean_v1.keras")

# %% [markdown]
# # Metrics

# %%
loss_curve = history.history["loss"]
acc_curve = history.history["accuracy"]

loss_val_curve = history.history["val_loss"]
acc_val_curve = history.history["val_accuracy"]

plt.plot(loss_curve, label="Train")
plt.plot(loss_val_curve, label="Val")
plt.legend(loc='upper left')
plt.title("Loss")
plt.show()

plt.plot(acc_curve, label="Train")
plt.plot(acc_val_curve, label="Val")
plt.legend(loc='upper left')
plt.title("Accuracy")
plt.show()

# %% [markdown]
# # Predict

# %% [markdown]
# ### Preprocessing

# %%
# audio = librosa.core.load(f'./genres/blues/blues.00000.wav')
# audio = librosa.core.load(f'./genres/blues/blues.00049.wav')
audio = librosa.core.load(f'./genres/disco/disco.00090.wav')
# audio = librosa.core.load(f'./genres/jazz/jazz.00097.wav')
y = audio[0]
sr = audio[1]

# Generate log power spectrogram
S = np.abs(librosa.stft(y))
spect = librosa.power_to_db(S**2, ref=np.median)

# Slice to have same shapes for all
spect = spect[:1000,:1220]

# Compress for the model
new_shape = (100,122)
block_height = spect.shape[0] // new_shape[0]
block_width = spect.shape[1] // new_shape[1]
downsampled_array = spect.reshape(new_shape[0], block_height, new_shape[1], block_width).mean(3).mean(1)

X = np.array([downsampled_array])

# %%
result = model.predict(X, verbose=2)
# Out:
# 1/1 - 0s - 72ms/epoch - 72ms/step

# %%
actual_best = 0
result_label = ""

for i in range(len(genres)):
    actual = result[0][i]
    if actual > actual_best:
        actual_best = actual
        result_label = genres[i]

print(result_label, str(actual_best))
# Out:
# disco 0.9131341
